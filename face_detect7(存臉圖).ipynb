# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/game/blob/master/face_detect7(%E5%AD%98%E8%87%89%E5%9C%96).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 將臉抓下存檔
# https://youtu.be/PmZ29Vta7Vc
#
# 15:43
# cv2.imwrite("111.png",gray_image)

# %% [markdown]
# # 1. 載入照片, 轉灰階圖
# https://thecodacus.com/opencv-python-face-detection/#.XAdTiIszaUk

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2
image = cv2.imread('face2.JPG')
plt.imshow(image)
plt.show()

# %%
img=image
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(imgrgb)
plt.show()

# %% [markdown]
# To use the face detection classifier we need to copy the classifier xml file from the “[opencv extracted folder]/sources/data/haarcascades/”, and then copy the file haarcascade_frontalface_default.xml to your project folder (same location where you will save the python program)
# Now thats done we can proceed further
# we can load the classifier now

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.show()

# %% [markdown]
# # 2. 自己上網下載frontalFace10.zip
# https://github.com/ZenithWest/AR-Drone-Project/tree/master/ADAPT/GlobalLib/data/haarcascades

# %%
# !wget http://alereimondo.no-ip.org/OpenCV/uploads/34/frontalFace10.zip

# !unzip  frontalFace10.zip
# Out:
# --2018-12-19 05:55:02--  http://alereimondo.no-ip.org/OpenCV/uploads/34/frontalFace10.zip
# Resolving alereimondo.no-ip.org (alereimondo.no-ip.org)... 181.167.183.203
# Connecting to alereimondo.no-ip.org (alereimondo.no-ip.org)|181.167.183.203|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 763850 (746K) [application/zip]
# Saving to: ‘frontalFace10.zip.1’
#
# frontalFace10.zip.1 100%[===================>] 745.95K   884KB/s    in 0.8s
#
# 2018-12-19 05:55:03 (884 KB/s) - ‘frontalFace10.zip.1’ saved [763850/763850]
#
# Archive:  frontalFace10.zip
# replace haarcascade_frontalface_alt_tree.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
detector = cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')

# %%
faces = detector.detectMultiScale(gray, 1.3, 5)

# %%
for (x,y,w,h) in faces:
  cv2.rectangle(imgrgb,(x,y),(x+w,y+h),(255,0,0),10)

# %%
plt.imshow(imgrgb)
plt.show()

# %% [markdown]
# # 3. 將臉抓下存檔

# %%
cv2.imwrite("111.png",imgrgb)
# Out:
# True

# %%
#找出臉部座標
(x,y,w,h)
# Out:
# (759, 228, 317, 317)

# %%
cv2.imwrite("222.png",imgrgb[y:y+h,x:x+w])
# Out:
# True
